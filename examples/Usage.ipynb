# %% [markdown]
# # Usage
#
# In principle the high-throughput pipeline allows for the calculation ∆∆Gbind of mutated complexes under the MM/PB(GB)SA framework in Amber wihtout the need for manual struture peraprtion.
#
#
# the high-throughput Alanine scanning pipeline. The pipeline is used
# for rapid single point Alanine mutations. It mutates a base PDB, generates all required
# input files for simulation, and then dispatches the simulations.
# (I want to insert a figuer here)
#
# the high-throughput pipeline for general in silico mutagenesis. Sim-
# ilar to the Alanine scanning pipeline in Figure 4, the pipeline encompasses all key steps for
# ∆∆Gbind predictions. The key difference is the MODELLER call which is used for single,
# multiple, and residue deletion
# (I want to insert a figuer here)
